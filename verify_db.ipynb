# %%
# %pip install requests

# %% [markdown]
# # Verify Database Setup
# This notebook checks if the Supabase tables are correctly set up.

# %%
import requests
import json

# Configuration
SUPABASE_URL = 'https://llvprbmrnjvamjzavmhg.supabase.co'
SUPABASE_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImxsdnByYm1ybmp2YW1qemF2bWhnIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc2NTc0NDU1MiwiZXhwIjoyMDgxMzIwNTUyfQ.yfdj690DOhgtlLXENe8nd5y22IFq5N1gtNZ2vnpHcKI'

HEADERS = {
    "apikey": SUPABASE_KEY,
    "Authorization": f"Bearer {SUPABASE_KEY}",
    "Content-Type": "application/json"
}

TABLES_TO_CHECK = [
    'users', 'profiles', 'admin_roles', 'wallets',
    'railway_bookings', 'transactions',
    'routes', 'bonds', 'blog_posts'
]

print(f"Checking database: {SUPABASE_URL}")
print("-" * 50)

for table in TABLES_TO_CHECK:
    url = f"{SUPABASE_URL}/rest/v1/{table}?select=*&limit=1&count=exact"
    try:
        response = requests.get(url, headers=HEADERS)
        if response.status_code == 200:
            # Get count from Content-Range header if available, or just check if list is returned
            content_range = response.headers.get('Content-Range', '0-0/0')
            total_count = content_range.split('/')[-1] if '/' in content_range else '?'
            
            data = response.json()
            status = "✅ Exists"
            count_str = f"({total_count} records)"
            print(f"{table:<20} {status} {count_str}")
        else:
            print(f"{table:<20} ❌ Error: {response.status_code} - {response.text}")
    except Exception as e:
        print(f"{table:<20} ❌ Exception: {str(e)}")
