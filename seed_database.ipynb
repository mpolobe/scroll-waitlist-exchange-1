# %%
import os
from supabase import create_client, Client

url = "https://llvprbmrnjvamjzavmhg.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImxsdnByYm1ybmp2YW1qemF2bWhnIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc2NTc0NDU1MiwiZXhwIjoyMDgxMzIwNTUyfQ.yfdj690DOhgtlLXENe8nd5y22IFq5N1gtNZ2vnpHcKI"

supabase: Client = create_client(url, key)

# Seed Loyalty Tiers
tiers = [
    {
        "name": "Bronze",
        "min_points": 0,
        "max_points": 999,
        "discount_percent": 0,
        "benefits": ["Priority booking access"]
    },
    {
        "name": "Silver",
        "min_points": 1000,
        "max_points": 4999,
        "discount_percent": 5,
        "benefits": ["5% discount on bookings", "Priority support"]
    },
    {
        "name": "Gold",
        "min_points": 5000,
        "max_points": 9999,
        "discount_percent": 10,
        "benefits": ["10% discount on bookings", "Free seat selection", "Priority boarding"]
    },
    {
        "name": "Platinum",
        "min_points": 10000,
        "max_points": 999999,
        "discount_percent": 15,
        "benefits": ["15% discount on bookings", "Free upgrades", "Lounge access", "Dedicated support"]
    }
]

for tier in tiers:
    try:
        data, count = supabase.table("loyalty_tiers").upsert(tier, on_conflict="name").execute()
        print(f"Seeded tier: {tier['name']}")
    except Exception as e:
        print(f"Error seeding tier {tier['name']}: {e}")

# Seed Users
users = [
    {
        "id": "bcaf0b57-107e-442c-919b-c9742edcd8e5",
        "email": "bcm32@njit.edu",
        "full_name": "Benjamin Mpolokoso",
        "country": "Zambia",
        "email_verified": False,
        "verification_token": "c4ba76a2-787a-407c-9065-50d8fdd29a9f",
        "verification_token_expires": "2025-11-29T00:28:26.338Z",
        "created_at": "2025-11-28T00:28:27.557Z",
        "updated_at": "2025-11-28T00:28:27.557Z"
    },
    {
        "id": "3a3adc5d-7d32-4824-bda9-ed1d8c81f7c2",
        "email": "globaltelecom2000@gmail.com",
        "full_name": "Global Telecom",
        "email_verified": False,
        "verification_token": "b4677c36-96b9-431f-b092-ef5ac49d5d19",
        "verification_token_expires": "2025-12-07T16:37:58.198Z",
        "created_at": "2025-12-06T16:37:59.089Z",
        "updated_at": "2025-12-06T16:37:59.089Z"
    }
]

for user in users:
    try:
        data, count = supabase.table("users").upsert(user, on_conflict="id").execute()
        print(f"Seeded user: {user['email']}")
    except Exception as e:
        print(f"Error seeding user {user['email']}: {e}")

# Seed Loyalty Points
points = [
    {
        "id": "52a03799-0cb7-4ce8-b0b3-57314456e384",
        "user_id": "bcaf0b57-107e-442c-919b-c9742edcd8e5",
        "points_balance": 15,
        "lifetime_points": 15,
        "tier_level": "Bronze",
        "tier_discount_percent": 0,
        "created_at": "2025-11-28T17:53:10.757Z",
        "updated_at": "2025-11-28T17:53:10.757Z"
    }
]

for point in points:
    try:
        data, count = supabase.table("loyalty_points").upsert(point, on_conflict="user_id").execute()
        print(f"Seeded points for user: {point['user_id']}")
    except Exception as e:
        print(f"Error seeding points: {e}")

# Seed Transactions
transactions = [
    {
        "id": "52a03799-0cb7-4ce8-b0b3-57314456e384",
        "user_id": "bcaf0b57-107e-442c-919b-c9742edcd8e5",
        "transaction_type": "earned",
        # "type": "earned",  <-- Removed
        "points_amount": 15,
        "points": 15,
        "booking_reference": "ARN-1764352388361",
        "description": "Earned 15 points from booking",
        "afc_amount": 155.00,
        "created_at": "2025-11-28T17:53:10.757Z"
    }
]

for tx in transactions:
    try:
        data, count = supabase.table("points_transactions").upsert(tx, on_conflict="id").execute()
        print(f"Seeded transaction: {tx['booking_reference']}")
    except Exception as e:
        print(f"Error seeding transaction: {e}")
# Out:
# Seeded tier: Bronze
# Seeded tier: Silver
# Seeded tier: Gold
# Seeded tier: Platinum
# Seeded user: bcm32@njit.edu
# Seeded user: globaltelecom2000@gmail.com
# Seeded points for user: bcaf0b57-107e-442c-919b-c9742edcd8e5
# Seeded transaction: ARN-1764352388361

# %%
# Verify Data
tables = ["loyalty_tiers", "users", "loyalty_points", "points_transactions"]

for table in tables:
    try:
        response = supabase.table(table).select("*", count="exact").execute()
        print(f"Table '{table}': {response.count} rows")
        if response.count > 0:
            print(f"Sample data from {table}: {response.data[0]}")
    except Exception as e:
        print(f"Error querying {table}: {e}")
# Out:
# Table 'loyalty_tiers': 4 rows
# Sample data from loyalty_tiers: {'id': 'c1e66860-4b61-4500-b654-159ca039291d', 'name': 'Bronze', 'min_points': 0, 'max_points': 999, 'discount_percent': 0, 'benefits': ['Priority booking access'], 'created_at': '2026-01-04T21:29:30.873454+00:00', 'updated_at': '2026-01-04T21:29:30.873454+00:00'}
# Table 'users': 2 rows
# Sample data from users: {'id': 'bcaf0b57-107e-442c-919b-c9742edcd8e5', 'email': 'bcm32@njit.edu', 'encrypted_password': None, 'created_at': '2025-11-28T00:28:27.557+00:00', 'updated_at': '2025-11-28T00:28:27.557+00:00', 'full_name': 'Benjamin Mpolokoso', 'country': 'Zambia', 'email_verified': False, 'verification_token': 'c4ba76a2-787a-407c-9065-50d8fdd29a9f', 'verification_token_expires': '2025-11-29T00:28:26.338+00:00', 'wallet_address': None, 'wallet_created_at': None}
# Table 'loyalty_points': 1 rows
# Sample data from loyalty_points: {'id': '52a03799-0cb7-4ce8-b0b3-57314456e384', 'user_id': 'bcaf0b57-107e-442c-919b-c9742edcd8e5', 'points': 0, 'tier': 'bronze', 'created_at': '2025-11-28T17:53:10.757+00:00', 'updated_at': '2025-11-28T17:53:10.757+00:00', 'points_balance': 15, 'lifetime_points': 15, 'tier_level': 'Bronze', 'tier_discount_percent': 0}
# Table 'points_transactions': 1 rows
# Sample data from points_transactions: {'id': '52a03799-0cb7-4ce8-b0b3-57314456e384', 'user_id': 'bcaf0b57-107e-442c-919b-c9742edcd8e5', 'points': 15, 'transaction_type': 'earned', 'description': 'Earned 15 points from booking', 'reference': None, 'created_at': '2025-11-28T17:53:10.757+00:00', 'points_amount': 15, 'booking_reference': 'ARN-1764352388361', 'afc_amount': 155.0}

# %%
# Final Verification
tables_to_check = ["users", "loyalty_tiers", "loyalty_points", "points_transactions", "admin_roles", "wallets", "profiles"]

print("=== Final Database Verification ===")
for table in tables_to_check:
    try:
        response = supabase.table(table).select("*", count="exact").execute()
        print(f"✅ {table}: {response.count} rows")
    except Exception as e:
        print(f"❌ {table}: Error - {e}")
# Out:
# === Final Database Verification ===
# ✅ users: 2 rows
# ✅ loyalty_tiers: 4 rows
# ✅ loyalty_points: 1 rows
# ✅ points_transactions: 1 rows
# ✅ admin_roles: 1 rows
# ✅ wallets: 2 rows
# ✅ profiles: 2 rows
